# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
import numpy as np

# %%
penguins = sns.load_dataset("penguins")

# %%
sns.ecdfplot(data=penguins, x="flipper_length_mm", hue="species")
plt.title("ECDF vs KDE of Flipper Length")
plt.show()

# %%
# Generate sample data
data = np.random.normal(loc=50, scale=10, size=500)  # Normally distributed data

plt.figure(figsize=(8,6))
sns.kdeplot(data, bw_adjust=0.2, label="bw=0.2")  # Less smoothing
sns.kdeplot(data, bw_adjust=1, label="bw=1")  # Default smoothing
sns.kdeplot(data, bw_adjust=2, label="bw=2")  # More smoothing
plt.legend()
plt.title("Effect of Bandwidth on KDE")
plt.show()

# %%
data1 = np.random.normal(40, 5, 500)
data2 = np.random.normal(60, 5, 500)

sns.kdeplot(data1, label="Group 1",  fill=True, bw_adjust=1.5)
sns.kdeplot(data2, label="Group 2",  fill=True, bw_adjust=1.5)
plt.legend()
plt.title("Comparing Two Distributions")
plt.show()

# %%
x = np.random.normal(50, 10, 500)
y = np.random.normal(30, 5, 500)

sns.kdeplot(x=x, y=y, cmap="Blues", fill=True)
plt.title("Bivariate KDE Plot")
plt.show()

# %%
iris = sns.load_dataset('iris')

# %%
sns.histplot(data['sepal_length'],bins=15, color='red', alpha=0.5, label='sepal_length',
         edgecolor='black', kde=True, binwidth=0.5)
plt.xlabel('sepal_length')
plt.ylabel('Frequency')
plt.title('Histogram of Sepal Length')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 sns.histplot(data['sepal_length'],bins=15, color='red', alpha=0.5, label='sepal_length',
#       2          edgecolor='black', kde=True, binwidth=0.5)
#       3 plt.xlabel('sepal_length')
#       4 plt.ylabel('Frequency')
#
# IndexError: only integers, slices (`:`), ellipsis (`...`), numpy.newaxis (`None`) and integer or boolean arrays are valid indices

# %%
fig, axes = plt.subplots(1,2, figsize=(10,5))

# Matplotlib Histogram
axes[0].hist(iris["sepal_length"], bins=10, color='blue', edgecolor='black')
axes[0].set_title("Matplotlib Histogram")
axes[0].set_ylabel('Frequency')
axes[0].set_xlabel('Sepal Length')

# Seaborn Histogram
sns.histplot(iris["sepal_length"], bins=10, kde=True, color='red', ax=axes[1])
axes[1].set_title("Seaborn Histogram")
axes[1].set_ylabel('Frequency')
axes[1].set_xlabel('Sepal Length')

plt.tight_layout()
plt.show()

# %%
fig, ax = plt.subplots()
ax.plot([10,5,8,9], [21,28,2,7])
plt.show

# %%
fig, axs = plt.subplots(2,2)
plt.show

# %%
np.random.seed(19680801)
data = {'a': np.arange(50),
'c': np.random.randint(0,50,50),
'd': np.random.randn(50)
}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

fig, ax = plt.subplots(figsize = (5, 2.7), layout = 'constrained')
ax.scatter('a', 'b', c='c', s='d', data=data)
ax.set_xlabel('entry a')
ax.set_ylabel('entry b')

# %%
x = np.linspace(0, 2, 100)
fig, ax = plt.subplots(figsize = (5, 2.7), layout = 'constrained')
ax.plot(x, x, label = 'linear')
ax.plot(x, x**2, label = 'quadratic')
ax.plot(x, x**3, label = 'cubic')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title('Simple Plot')
ax.legend()

# %%
x = np.linspace(0, 10, 100)

plt.figure(figsize=(10, 6))

# Define a 2x2 grid and place subplots
plt.subplot(2, 2, 1)  # First subplot (row=1, col=1)
plt.plot(x, np.sin(x))
plt.title("Sine Function")

plt.subplot(2, 2, 2)  # Second subplot (row=1, col=2)
plt.plot(x, np.cos(x))
plt.title("Cosine Function")

plt.subplot(2, 2, 3)  # Third subplot (row=2, col=1)
plt.plot(x, np.tan(x))
plt.title("Tangent Function")

plt.subplot(2, 2, 4)  # Fourth subplot (row=2, col=2)
plt.plot(x, np.exp(-x))
plt.title("Exponential Decay")

plt.tight_layout()  # Adjusts spacing
plt.show()

# %%
# Generate sample data
data = np.random.rand(10, 10)

# Create figure and axis
fig, ax = plt.subplots()
cax = ax.imshow(data, cmap='plasma')

# Add colorbar
fig.colorbar(cax, orientation='horizontal')

plt.title("Basic Colorbar Placement")
plt.show()

# %%
fig, ax = plt.subplots()
x = np.random.rand(100)
y = np.random.rand(100)
colors = np.random.rand(100)

sc = ax.scatter(x, y, c=colors, cmap='jet')
fig.colorbar(sc)

plt.title("Scatter Plot with Colorbar")
plt.show()

# %%
x = np.linspace(-2, 2, 100)
y = np.linspace(-2, 2, 100)
X, Y = np.meshgrid(x, y)
Z = np.exp(-X**2 - Y**2)

fig, ax = plt.subplots()
contour = ax.contourf(X, Y, Z, cmap='coolwarm')
fig.colorbar(contour)

plt.title("Contour Plot with Colorbar")
plt.show()

# %%
# Load dataset
diamonds = sns.load_dataset("diamonds")

# Create a scatter plot of price vs carat
plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)
plt.scatter(diamonds["carat"], diamonds["price"], alpha=0.3)
plt.xscale('linear')
plt.yscale('linear')
plt.xlabel("Carat")
plt.ylabel("Price")
plt.title("Linear Scale")

plt.subplot(1, 2, 2)
plt.scatter(diamonds["carat"], diamonds["price"], alpha=0.3)
plt.xscale('log')
plt.yscale('log')
plt.xlabel("Carat (log scale)")
plt.ylabel("Price (log scale)")
plt.title("Logarithmic Scale")

plt.tight_layout()
plt.show()

# %%
# Sample data
data = np.random.rand(10, 10)

# Create figure
fig, ax = plt.subplots()

# Display the image with a color mapping
cax = ax.imshow(data, cmap='viridis')

# Add colorbar
fig.colorbar(cax, orientation='horizontal')

plt.show()

# %%
# Load iris dataset
iris = sns.load_dataset("iris")

# %%
# Define colors for each species
colors = {'setosa': 'red', 'versicolor': 'blue', 'virginica': 'green'}

# Create scatter plot
plt.figure(figsize=(8,6))

for species in iris['species'].unique():
    subset = iris[iris['species'] == species]
    plt.scatter(subset['sepal_length'], subset['sepal_width'], 
                label=species, color=colors[species])

# Adding labels and title
plt.xlabel("Sepal Length")
plt.ylabel("Sepal Width")
plt.title("Iris Sepal Dimensions")

# Add legend
plt.legend(title="Species", loc="upper right", fontsize=12, frameon=True)

# Show plot
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.scatterplot(data = iris, x = iris['sepal_width'], y = iris['sepal_length'],
                hue = 'species',)

# %%
iris = sns.load_dataset("iris")
plt.figure(figsize=(8,6))   
sns.swarmplot(data = iris, x = iris['species'], y = iris['sepal_length'],hue = 'species', dodge = True)
plt.title("Swarm Plot of Sepal Length by Species")
plt.show()
